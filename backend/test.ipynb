# %%
import plotly.graph_objects as go
import numpy as np
from scipy.stats import norm, gamma, expon

# Define parameters for the normal distribution
mean = 0
std_dev = 1

# Generate a range of x values
x_values = np.linspace(-5, 5, 1000)

# Calculate the corresponding probability density function (PDF) values
pdf_values = norm.pdf(x_values, mean, std_dev)

# Create a Plotly figure
fig = go.Figure()

# Add a trace for the normal distribution
fig.add_trace(go.Scatter(x=x_values, y=pdf_values, mode='lines', name='Normal Distribution'))

# Update layout
fig.update_layout(
    title='Theoretical Normal Distribution',
    xaxis=dict(title='X-axis'),
    yaxis=dict(title='Probability Density Function (PDF)'),
    showlegend=True
)

# Show the interactive plot
fig.show()

# %%
import scipy.stats as stats

def get_distribution_parameters(distribution_name):
    distribution = getattr(stats, distribution_name)

    # Get the parameters from the distribution class
    parameters = distribution.shapes

    return parameters

# Example usage for the normal distribution (mu and sigma)
distribution_name = "norm"
parameters = get_distribution_parameters(distribution_name)
print(parameters)
# Out:
# None

# %%
import scipy.stats as stats 
abc = getattr(stats, "alpha")
abc.shapes
# Out:
# 'a'
